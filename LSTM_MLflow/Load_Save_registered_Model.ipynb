# %%
import mlflow

# Make sure the client points to your server
mlflow.set_tracking_uri("http://127.0.0.1:5000")  # or your remote server

# %%
import mlflow
import tensorflow as tf

MODEL_NAME = "Best_LSTM_Model"
MODEL_VERSION = "1"

model = mlflow.keras.load_model(f"models:/{MODEL_NAME}/{MODEL_VERSION}")

# export as TensorFlow SavedModel
#model.export("model_saved")
model.save("best_model.keras")

# model.save("model_saved", save_format="keras") # this is keras_metadata.pb
# Out:
# C:\Users\JH\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# ...
